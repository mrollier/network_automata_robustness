# %% [markdown]
# Authors:
#
# - Michiel Rollier
# - João Vitor Merenda
# - Lucas Caldeira de Oliveira
#
# To do:
# - Read "[Understanding Convolutions on Graphs](https://distill.pub/2021/understanding-gnns/)"
# - Look at Teo's suggestions:
#     - https://pubmed.ncbi.nlm.nih.gov/18851664/
#     - https://www.researchgate.net/publication/318135374_Loop-centrality_in_complex_networks
#     - https://www.sciencedirect.com/science/article/pii/S2352864822001912
#     - https://www.nature.com/articles/s42005-021-00781-3

# %%
# numeric simulation
import numpy as np
import torch as tc
import torch_geometric as tg

# %%
# utilities and visualization
import sys
import igraph as ig
import networkx as nx
from matplotlib import pyplot as plt

# %%
# personal library
from src.datasets import NetworksDataset
from src.automata import LLNA
from src.simulation import *
from src.analysis import jacobian, defect_diameter, calculate_Yt, lyapunov_spectrum

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Patterns and Recomendations

# %% [markdown]
# ## color codes
#
# <font color='purple'>Comments and annotations writen by Lucas will be in <b>purple</b>.</font>
#
# <font color='green'>Comments and annotations writen by Michiel will be in <b>green</b>.</font>
#
# <font color='brown'>Comments and annotations writen by João will be in <b>brown</b>.</font>
#
# <font color='red'>Wrong/inconsistent stuff will be marked in <b>red</b> regardless of the author.</font>
#
# ## included libraries
#
# Let's keep all `import`s in the begining, and be specific of what we are using. Said so, try to avoid `import *` because we don't know what is being imported and it can cause conflicts in the code.

# %% [markdown]
# # 0 - Table of Symbols

# %% [markdown]
# <font color='green'>
# Note: I think it's better to follow the notational convention used by Milan, Vichniac, Bagnoli, etc.
#
# Note: the notation related to the Lyapunov spectrum is optimal in the Notebook 'lyapunov-sanity-check.ipynb'.
# </font>
#
# <font color='purple'> Working on it</font>

# %% [markdown]
# - $\mathcal{G} = (\mathcal{V}, \mathcal{E})$: a simple graph defined based on its nodes and edges
# - $\mathcal{V} = \{v\}$: set of nodes (or cells);
# - $\mathcal{E} = \{(v_i, v_j)\}$: set of unweighted edges;
# - $\mathbf{A} = [a_{i,j}] \in \{0;1\}^{|\mathcal{V}| \times |\mathcal{V}|}$: binary adjacency matrix where $a_{i,j} = 1$ denotes the existence of the edge $(v_i, v_j)$;
# - $\mathbf{D} = [d_{i,j}] \in \mathbb{N}^{|\mathcal{V}| \times |\mathcal{V}|}$: the degree matrix, which supposes that all nodes are connected _i.e._ there are no zeros in the main diagonal;
# - $\mathcal{N}(v_i) = \{v_j~|~\forall j : a_{i,j} \neq 0 \}$: the neighbourhood of node $v_i$.
# - $\mathcal{C} = \langle \mathcal{T}, \mathbb{S}, \vec{x}^0, \phi \rangle$: automaton defined on a tesselation $\mathcal{T}$, a set of all possible discrete states $\mathbb{S} = \{s_0, ... s_{k-1}\}$, an initial configuration $\vec{x}^0$ and a transition function $\phi : \mathbb{S}^{|\mathcal{N}|} \to \mathbb{S}$;
# - $\vec{x}^t = [x(v_i,t)] \in \mathbb{S}^{|V|}$: state vector of $i$-th nodes at time step $t$;
# - $\delta\vec{x}^t$: disturb vector at time step $t$;
# - $\mathbf{H} = \left[ \vec{x}^t \right] \in \mathbb{S}^{|\mathcal{V}| \times T}$ state matrix of nodes evolved by $T$ steps (i.e. time evolution patterns);

# %% [markdown]
# <div style="color: purple; border: thin solid purple; padding: 10px;">
# Update summary:
#
# - At some places, the notation of cell $v_i$ and cell state $x(v_i, t)$ were used indistinctly. This was corrected by using $v_i$ when refering to the "entity" of the node, which doesn't change over time and therefore should not have a $t$ superscripted or subscripted; and using $x(v_i, t)$ when refering to its "property" called state which does change over time and therefore needs a $t$ specified.
# - There are two possible ways to specify the time: superscripted ($\vec{x}^t$) or subscripted ($\vec{x}_t$). I'll be using the superscripted format.
# - I'm adding arrows to mark every vector, and letting all matrices in bold. It can make the equations a little more "heavy" to the eyes but improves understanding.
# </div>

# %% [markdown]
# # 1 - Introduction

# %% [markdown]
# **A not so formal discussion**
#
# In this work we want to **investigate the robustness** of a class of deterministic network automata called Life-Like Network Automata (LLNA). Here, we call Network Automata (NA) any Cellular Automata (CA) algorithm runned on networks, a kind of irregular tesselation that doesn't have a fixed number of neighbors per cell neither possesses an explicit ordering of cells in the teselation and also in their neighborhoods.
#
# <font color='purple'>Ideas for the characterization of LLNA rules:
# - how the lyapunov exponent/spectrum is related to node measures?
# - does the maximum/minimum size of the continuous subinterval of born/survive rule interfeers in the robustness? (insight: more transitions between enabled/disabled subintervals means more sensibility in face of small perturbations in the neighborhood)
# </font>
#
# A common way to assess this problem is by the Lyapunov exponent, which measures the damage spreading due to minimal perturbations (disturbs). Although it is well defined for continuous-time systems, it lacks a generic formalism for discrete-time systems as CAs, making this understanding not so trivial.
#
# <font color='purple'>May be good to check the following papers as well for additional definitions:
# - Shereshevsky (1991): "Lyapunov exponents for one-dimensional cellular automata";
# - Bagnoli et al (1992): "Damage spreading and Lyapunov exponents in cellular automata";
# - Baetens and De Baets (2010): "Phenomenological study of irregular cellular automata based on Lyapunov exponents and Jacobians";
# - Vispoel et al (2024): "Damage spreading and the Lyapunov spectrum of cellular automata and Boolean networks".</font>

# %% [markdown]
# **About "_Lyapunov exponents in random Boolean networks_"**
# <font style="color: purple">(to be reviewed by the other authors)</font>
#
# We can start our study mentioning the work of Luque and Solé (2000), which proposes a new order parameter based on the concept of boolean derivatives (Vichniac, XXXX) as a way to calculate the (largest) Lyapunov exponent $\lambda$ in RBNs. The first thing to notice is that RBNs are defined based on the (fixed) neighborhood size $K$; yet it is possible to vary $K$ in a continuous range by using the average value $\overline{K}$.
#
# As this class of systems will always present periodic patterns after a maximum of $2^N$ steps (with $N$ being the number of cells), it is not trully chaotic, so they use a definition of chaotic behavior in terms of damage spreading: if the damage $\mathbf{d}(t)$ vanished after a fixed number of iterations, the system is said to be at frozen/ordered phase ($\lambda < 0$); instead, if the damage spreading reaches rate a fixed non-zero value, its said to be at chaotic/disordered phase ($\lambda > 0$).
#
# Maybe the most important parameter in this paper is the bias $p$: the probability that a random boolean function $f$ outputs 1's. Without explaining how, they say that $p$ also stands for $f'$, implying that a disturb will not change the average number of 1's at the output. And as they use it for a mean-field aproximation for $t \to \infty$, I can infer that this insensitity to disturbs, in terms of average behavior of the boolean functions, is valid for small perturbations but also for big, accumulated perturbations.
#
# Anyway, the great proposition is the definition of Lyapunov exponent for RBNs, so:
#
# $$
# \lambda = \lim_{T \to \infty} \frac{1}{T} \sum_{t=1}^T log\frac{|\mathbf{d}(t+1)|}{|\mathbf{d}(t)|}
# \approx log(2p(1-p)K)
# $$

# %% [markdown]
# **About "_On the topological sensitivity of cellular automata_"**
# <font style="color: purple">(to be reviewed by the other authors)</font>
#
# Following to the next highlighted paper, the work of Baetens and Bates (2011) graps the question: what if, instead of measuring the sensitivity of a CA related to state perturbations, we measure its sensitivity about topological perturbations? And with "topological perturbation" they meant to keep the same state but evolve it with similar topologies, by adding/removing edges.
#
# To achieve this, it's proposed (i) topological derivatives and (ii) topological Lyapunov exponents, both for irregular tesselations, and then validated with 256 (regular) ECAs and 2D irregular totalistic CAs. The algorithm for computate the Maximum Topologic Lyapunov Exponent - MTLE (oposed to traditional MLE) has exponential complexity as it will iterate every divergence in phase space to check if it can produce new divergences, and then repeat it to the next time step.
#
# Besides the rich reasoning about how to alter the definitions of classical MLE and the jacobian to support other necessities, I doubt that the discoveries contained in this paper can deeply help us. In my opinion, these are the main downsides:
# - they investigate the impact in phase space of adding/removing edges, which is much more complex than simply disturb and measure state vector directly;
# - the algorithm seems to have impractical computational complexity when dealing with real networks (for instance, imagine the explosion of simulation time when tracking all expansions of disturbs in a scale-free networks after reaching a hub node);
# - the type of automata they are dealing with are strongly impacted by any change in the size of the neighborhood (in terms of transition function), what is not the case here.

# %% [markdown]
# ## 1.1 - Cellular Automata, graph theory and network automata

# %% [markdown]
# ### _1.1.x - Life-like network automata with resolution R_
#
# The Game of Life is defined in a two-dimensional regular grid where every cell has a Moore neighbourhood (8 neighbours + the "zero" condition), and (copied from Zielinski et al. 2022)
# - Any live cell with fewer than two life neighbours will die of loneliness,
# - Any live cell with more than three live neighbours will die of over-crowding,
# - Any live cell with two or three live neighbours will survive,
# - Any dead cell with three live neighbours will be born,
#
# It is sumarized by the notation $B_{3}S_{2,3}$, in terms of the amount of alive neighbors needed to _born_ or _survive_. The subscript can be any combination between zero and the maximum possible size of the neighborhoods ($0, 1, \dots 8$). As there are 9 possible quantities for aline cells in the neighborhood, we call it the *resolution* of the rule, which in this case is $R = 9$.
#
# - To avoid misunderstandings, we will denote the life-like rules in the explicit form `R=9:B3_S2,3`. So, first we denote the resolution and after it we put the born-condition indices and then the survive-condition indices, all separated by commas.
#
# This can be generalised to a network, but the issue now is that there is no fixed number of neighbours. If we want to formulate a uniform rule, we will therefore have to define it in terms of densities (fraction of neighbours), rather than the absolute number of neighbours:
# $$
# \rho(v_i,t) = \frac{1}{|\mathcal{N}(v_i)|}\sum_{v_j \in \mathcal{N}(v_i)} x(v_j,t),
# $$
#
# $$
# \vec{\rho}^t = \mathbf{D}^{-1} \mathbf{A} \vec{x}^t
# $$
# such that $0 \leq \rho(v_i,t) \leq 1$.
#
# Now we can define a general Life-like network automaton (LLNA) rule, by indicating:
# - When the node is dead, for what neighbourhood densities should it be born?
# - When the node is alive, for what neighbourhood densitities should it survive?
#
# Because the density parameter can be any value from $0$ to $1$, there is an infinite number of possible LLNA rules. In order to impose a meaningful structure in this infinite possiblities, we discretise the density domain into a number of subdomains (the "resolution"). We associate each of these subdomains with a particular binary outcome (alive or dead).
#
# As an example, consider the resolution $R=4$. This allows for $4^2 \times 4^2 = 256$ possible LLNA rules. If each of the density domains is associated with death (i.e. nobody borns or survives), we simply write this as rule `R=4:B_S`. If each of the density domains is associated with life (i.e. everybody borns and survives), we write `R=4:B0123_S0123`. Below is a visualisation of rule `R=4:B01_S03`.

# %%
SAVEFIG=False

resolution = 4
born_if = [0,1]
survive_if = [0,3]
model = LLNA(resolution, x=born_if, y=survive_if)
fig, ax = model.diagram()

if SAVEFIG:
    plt.savefig(f"figures/LLNA_diagram_example.pdf", bbox_inches='tight')

# %% [markdown]
# <font color='green'>
# <b>NOTE</b>: the left border of each domain is included, and the right border is not, except for the final domain, where both borders are included. So for the example above, a live cell with a concentration of exactly $1/4$ would die.
# </font>

# %% [markdown]
# Note that this definition in terms of density works for varied size of neighborhoods, which is desired when dealing with graphs in general, but also works for the original Game of Life.
#
# Also, if we create a graph that is based on the Moore's neighborhood and apply the density-based rule with same encoding and resolution, the results will be identic. To achieve this, we map each possible count (dots) to its respective density subinterval (hatched areas), as can be seen in the figure below.

# %%
plt.figure(figsize=(10,3))
cmap = plt.get_cmap('Set1')
rmax = 9
for r in range(rmax):
    params = plt.stem([r], [1], label=f'count = {r}')
    for p in params:
        plt.setp(p, color=cmap(r))
    plt.fill_between([r, r+1], [1]*2, alpha=.2, hatch='/', facecolor=cmap(r), edgecolor=cmap(r))
    brk = '[' if r < rmax-1 else ']'
    plt.text(0.5+r, 0.5, f'[{r}/9, {r+1}/9{brk}', fontsize=8, ha='center')
plt.xticks(np.arange(0, rmax+1))
plt.title('Relation between count and density of alive neighbors')
plt.show()

# %% [markdown]
# The LLNA rule space has the size of $2^R$ born conditions and $2^R$ survive conditions, with a total of $2^R \times 2^R$ possible rules.
#
# We will first work with a resolution of 2, such that there are only 16 transition rules to explore. This will most probably limit the dynamical richness of the system. Yet, considering the large number of other (network) variations, this is a good first step.
#
# <font color='purple'><b>[TO-DO]</b> bring the LLNA formal equations from related papers</font>

# %% [markdown]
# ## 1.2 - Definition, interpretation and relevance of robustness

# %% [markdown]
# Let $\mathcal{G}(\mathcal{V}, \mathcal{E})$ denote a network with $N$ nodes (or cells), $\mathcal{V} = \{v_1, v_2, v_3, \cdots , v_N\}$ and $|\mathcal{E}|$ edges. Let $\mathbb{S} = \{0,1\}$ denote the set of all possible states of a cell. Thus, the configuration space of the network is $\mathbb{S}^N$. Consider $\mathcal{N} (v_i)$ as the neighborhood set of the node $v_i$. The transition function, denoted by $\phi : \mathbb{S}^{|\mathcal{N} |} \rightarrow \mathbb{S}$, specifies that the state transition of node $v_i$ is influenced by its neighborhood.
#
# This transition function $\phi$ establishes a global mapping $\Phi : \mathbb{S}^N \rightarrow \mathbb{S}^N$, where $x(v_i, t+1) = \Phi_i (\vec{x}^t)$, and $\vec{x}^t = [x(v_1,t) \cdots  x(v_N,t)]$ is the state vector at time $t$. We can denote the initial state vector as $\vec{x}^0$.
#
# Also, for simplification purposes, we will denote $t$ applications of $\Phi$ as $\Phi^t$. For example,
#
# $$\vec{x}^3 = \Phi(\Phi(\Phi(\vec{x}^0))) \equiv \Phi^3(\vec{x}^0).$$

# %% [markdown]
# **Boolean derivatives and the Jacobian**

# %% [markdown]
# Let $\{\vec{e}_i\}$ be the standard basis: $\vec{e}_i \in \mathbb{S}^N$ is a vector that has 1 only at coordinate $i$, and 0 at other ones, and the following expansion, where $\oplus$ is the XOR operator (module-2 summation) (Baetens and De Baets 2011).
#
# $$\vec{x}^t \oplus \vec{e}_i = [x(v_1, t), \cdots , x(v_i, t) \oplus 1, \cdots , x(v_N, t)]$$
#
# <br>
# <font color='purple'>
# In Luque and Solé (2000) the global mapping $\mathbf{F}(t) = [ f_i(x^t) ]$, represented here by $\Phi(\vec{x}^t) = [\phi(x_i^t)]$, produces the following relation.
#
# $$
# F'_{i,j} = \frac{\partial f_i(x_i^t)}{\partial x_j^t} =
# \begin{cases}
#     f_i(\vec{x}^t) \oplus f_i(\vec{x}^t \oplus \vec{e}_j)
#         & \text{if}\;x_j\;\text{"inputs"}\;x_i\\
#     0 & \text{otherwise} \\
# \end{cases}
# $$
#
# Can it be simplified to remove the cases, as writen below?
# </font>
# <br>
#
# Given the definitions above, we can define the Boolean derivative.
#
# $$
# \frac{\partial x(v_i,t+1)}{\partial x(v_j,t)}
#  = \left.\frac{\partial \Phi_i}{\partial x_j}\right|_t
#  = \Phi_i(\vec{x}^t) \oplus \Phi_i(\vec{x}^t \oplus \vec{e}_j)
# $$
#
# The Boolean derivative will be $1$ if and only if a changing in the $v_j$ state at time $t$ can induces a transition in the state of $v_i$ at time $t + 1$.
#
# Let $\vec{x}^0$ be the initial state of all cells and $\vec{x}^t$ the state at time $t$, then the Jacobian is defined by:
#
# $$
# \mathbf{J}(\vec{x}^t) = \left[ \left.\frac{\partial \Phi_i}{\partial x_j}\right|_t \right]
#  = \begin{bmatrix}
#     \left.\frac{\partial \Phi_1}{\partial x_1}\right|_t & \dots &
#     \left.\frac{\partial \Phi_1}{\partial x_N}\right|_t \\[5pt]
#     %
#     \vdots & \ddots & \cdots \\[5pt]
#     %
#     \left.\frac{\partial \Phi_N}{\partial x_1}\right|_t & \dots &
#     \left.\frac{\partial \Phi_N}{\partial x_N}\right|_t \\[5pt]
# \end{bmatrix}
# $$
#
# The Jacobian describes how $N$ mutually orthogonal perturbations propagate from the time $t$ to time $t+1$.

# %% [markdown]
# **Configuration space**

# %% [markdown]
# The configuration space represents all nodes and their respective states within a network. In the context of a network, this space is represented as $\mathbb{S}^N$, constituting an $N$-dimensional domain.
#
# Consider $\vec{x}^0$ as the initial configuration. A perturbation, or defect, denoted by $\delta \vec{x}^0$, induces a deviation in the trajectory within the configuration space over a time period $T$. Let $\Delta \vec{x}^0$ be the difference pattern between the original trajectory on configuration space and the disturbed trajectory at step zero. This value can be measured by:
#
# $$ \Delta \vec{x}^0 = (\vec{x}^0) \oplus (\vec{x}^0 \oplus \delta\vec{x}^0) = \delta\vec{x}^0 $$
#
# For further steps,
#
# $$ \Delta \vec{x}^t = \Phi^t(\vec{x}^0) \oplus \Phi^t(\vec{x}^0 \oplus \delta\vec{x}^0) $$
#
# Therefore, $\Delta \vec{x}^t$  measures the displacement of the trajectories caused by a perturbation at the initial time. We can investigate whether such perturbations lead to convergence or divergence in the trajectories within the configuration space evolving them by the Jacobian.
#
# $$
#     \Delta \vec{x}^{t+1} = \mathbf{J}(\vec{x}^t) \otimes \Delta \vec{x}^t
# $$
#
# <font color='green'>
# <b>NOTE</b> this is probably not true! The Jacobian is only really useful in tangent space (cf. the toy example below: the perturbation is not evolved properly)
# </font>
#
# This equation stands as long as the perturbation has unitary length ($\delta\vec{x} = \vec{e_i}$ for a defect in cell $i$) or is composed by a sum of unitary perturbations in cells that are not neighbors.
#
# Additionally, this equation operates recursively, meaning that to determine the difference pattern at time $t + 1$, we first calculate the difference pattern at time $t$. In turn, computing the difference pattern at time $t$ requires considering the difference pattern at time $t - 1$, and so forth. Here, the operator $\otimes$ denotes standard matrix multiplication, with the addition operation substituted by $\oplus$.
#
# Convergence of $\Delta \vec{x}^{t+1}$ means stability, while exponential divergence suggests chaotic behavior.

# %% [markdown]
# **Lyapunov exponent on configuration space formalism**

# %% [markdown]
# In the configuration space, the Lyapunov exponent (LE) quantifies the rate of growth of the difference pattern between the original trajectory and the perturbed trajectory. The LE for a time step, as introduced in \cite{luque2000lyapunov}, is defined as follows:
#
# $$ \lambda (T) = \frac{1}{T}\sum_{t = 0}^T\log\left(\frac{|\Delta \vec{x}^{t+1}|}{|\Delta \vec{x}^t|}\right) $$
#
# $$ \lambda (T) = \frac{1}{T}\,\log\left(\frac{|\Delta \vec{x}^{t+1}|}{|\Delta \vec{x}^0|}\right) $$
#
# $$ \lambda (T) = \frac{1}{T}\,\log\left(|\Delta \vec{x}^{t+1}|\right) $$
#
# where $|\Delta \vec{x}^{t+1}| = \sum_{i=1}^N \Delta x^{t+1}_i$. Based on this we can generalize the Lyapunov exponent as
#
# $$ \lambda = \lim_{T \to \infty} \lambda(T) .$$
#
# Note that for finite networks, this will always go to zero at limit $T\rightarrow\infty$ (due to the normalization factor), so we need to find a good cut-off value.

# %% [markdown]
# <font color='purple'>
# Let supose that after time step $T_\text{peak}$ the damage reached the entire network and cannot grow in size anymore, impling in $|\Delta \vec{x}^{T_\text{peak}+t}| \le |\Delta \vec{x}^{T_\text{peak}}| \;\forall t \in \mathbb{N}^*$. Also note that the size of damage at this point is limited by the size of the network itself: $|\Delta \vec{x}^{T_\text{peak}}| \le N$.
#
# If we analyze the LE for $T \ge T_\text{peak}$ we have:
#
# $$ \lambda(T) = \frac{1}{T}\sum_{t = 0}^T\log\left(\frac{|\Delta \vec{x}^{t+1}|}{|\Delta \vec{x}^t|}\right) $$
#
# $$
# \lambda(T) = \frac{1}{T} \left(
#     \sum_{t = T_\text{peak}}^{T} \log\left(\frac{|\Delta \vec{x}^{t+1}|}{|\Delta \vec{x}^t|}\right) +
#     \sum_{t = 0}^{T_\text{peak}} \log\left(\frac{|\Delta \vec{x}^{t+1}|}{|\Delta \vec{x}^t|}\right)
# \right)
# $$
#
# $$
# \lambda(T) = \frac{1}{T} \left(
#     \log\left(\frac{|\Delta \vec{x}^{T}|}{|\Delta \vec{x}^{T_\text{peak}}|}\right) +
#     \log\left(\frac{|\Delta \vec{x}^{T_\text{peak}}|}{|\Delta \vec{x}^{0}|}\right)
# \right)
# $$
#
# If the damage keeps its size, then $|\Delta \vec{x}^{T_\text{peak}+t}| = |\Delta \vec{x}^{T_\text{peak}}| \;\forall t \in \mathbb{N}^*$ and therefore the first logarithm is zero, which give us is the maximum possible for these particular initial configuration and disturb.
#
# $$ \lambda_\text{peak} = \frac{1}{T_\text{peak}} \log\left(\frac{|\Delta \vec{x}^{T_\text{peak}}|}{|\Delta \vec{x}^{0}|}\right) $$
#
# The other options are that the disturb will shrink untill vanishing, will shrink a little and then saturate at some value lower than $|\Delta \vec{x}^{T_\text{peak}}|$ or will oscillate. In the first scenario the LE goes to zero by the vanishing of the disturb, in the second and third scenarios it will approach a non-zero value lower than $\lambda_\text{peak}$. But regardless of this, if we take the limit $T \to \infty$ the LE will always become zero.

# %% [markdown]
# <font color='purple'>
# Although its hard to define an ideal value for $T$, we can think about the what could be the minimum amount of time steps required for a perturbation to propagate from a node $v_i$ to all other ones, which is related to the average distant between a root node $v_i$ and the leaves of its spanning tree.
#
# Let $\text{dist}(v_i, v_j)$ be the shortest distance between nodes $v_i$ and $v_j$. If all nodes can be reached by any node in the network and there are no disconnected nodes (_i.e._ only one connected component), we can measure the average geodesic distance (Costa et. al., 2007) by
#
# $$ \ell = \frac{1}{N(N-1)} \sum_{i \neq j} \text{dist}(v_i, v_j) .$$
#
# Setting a fixed starting node $v_i$, the average distance between it and the other nodes is given by $\ell_i = (N-1)^{-1} \sum_{j \neq i} \text{dist}(v_i, v_j)$. Then, taking the initial disturb $\delta\vec{x}^{0} = \vec{e}_i$ we can limit the time steps to compute LE by $\ell_i$:
#
# $$ \lambda_i = \lim_{T \to \ell_i} \left.\lambda(T)\right|_{\delta\vec{x}^{0} = \vec{e}_i} $$
#
# $$
# \lambda_i = {\ell_i}^{-1} \log\left(\left|
#     \Phi^{\ell_i}(\vec{x}^0) \oplus \Phi^{\ell_i}(\vec{x}^0 \oplus \delta\vec{e}_i)
# \right|\right)
# $$
# </font>

# %%
#Configuration space
def conf_space(G, model, s0, s0_defect, T):
    #Delta x0 calculation:
    N = len(s0)
    edges = G.get_edgelist()
    D0 = np.mod(s0 ^ s0_defect, 2)  #initial difference between the two configurations
    D = D0 #initializing at t = 0
    states_original = np.tile(s0, (T,1)) # all states (will be updated in the loop)
    Js = np.zeros(shape=(T-1,N,N)) #Allocate space for Jacobian
    for t in range(1,T):
        states_original[t] = np.array(model.step(tc.tensor(edges).T, tc.tensor(states_original[t-1])))
        Js[t-1] = jacobian(G, model, states_original[t])
        #Delta x^t = Js * Delta x^t-1
        D = np.mod(np.matmul(Js[t-1], D),2)
    #Here, the Lyapunov exponent
    L = np.log(sum(D)/sum(D0))/T
    return L

# %% [markdown]
# **Tangent Space**

# %% [markdown]
# The tangent space of a CA is a conceptual space that allows for the analysis of how small perturbations or defects evolve in the system. It is analogous to the tangent space in continuous-state dynamical systems, where it represents the space of all possible directions in which perturbations can grow or shrink. This space is essentially a vectorial space, delineated by the tangent vector at a point $P \in \mathbb{S}^N$, and it exhibits an isomorphism with the space $\mathbb{S}^N$. The advantage of working with perturbations in tangent space is that we only need to keep track of the evolution of $n$ mutually orthogonal perturbations.
#
# The tangent space has the linearity property, it means that we can decompose the perturbation vector into a complete and orthogonal set of vectors representing the perturbation in each direction: $\delta \vec{x}^t = \sum_{i=1}^N\delta x_i^t\vec{e}_i$. These components evolve in accordance with the Jacobian:
#
# $$
# \begin{bmatrix}
#     \delta x_1^{t+1} \\[10pt]
#     \delta x_2^{t+1} \\
#     \vdots \\[10pt]
#     \delta x_N^{t+1} \\[10pt]
# \end{bmatrix}
#  = \begin{bmatrix}
# \frac{\partial \Phi_1}{\partial x_1}|_t & \frac{\partial \Phi_1}{\partial x_2}|_t & \cdots & \frac{\partial \Phi_1}{\partial x_N}|_t \\[10pt]
# \frac{\partial \Phi_2}{\partial x_1}|_t & \frac{\partial \Phi_2}{\partial x_2}|_t & \cdots & \frac{\partial \Phi_2}{\partial x_N}|_t  \\
# \vdots & \vdots &  & \vdots \\
# \frac{\partial \Phi_N}{\partial x_1}|_t & \frac{\partial \Phi_N}{\partial x_2}|_t & \cdots & \frac{\partial \Phi_N}{\partial x_N}|_t \\[10pt]
# \end{bmatrix}
# \begin{bmatrix}
#     \delta x_1^{t} \\[10pt]
#     \delta x_2^{t} \\
#     \vdots \\[10pt]
#     \delta x_N^{t} \\[10pt]
# \end{bmatrix}
# \Leftrightarrow \delta \vec{x}^{t+1} = \mathbf{J}(\vec{x}^t)\delta\vec{x}^t
# $$
#
# <font color='purple'>The following part was bring from the old overview file. It seems to me that it is usefull, but I'll let it marked.</font>
#
# Being the tangent space linear, and decomposing the perturbation vector by a sum of its orthonormal componentes, we can build a matrix $\mathbf{Y}^0$ which represents all orthogonal perturbations that form the basis of the tangent space and, given such orthogonality, this matrix is the identity matrix. This matrix symbolize a sphere of perturbation emanating from the initial state.
#
# The temporal evolution, as well as in the configuration space, is given by the Jacobian, but instead of evolving the difference pattern vector, we will evolve the matrix $Y^t$ from $Y^0$
#
# $$
#     \mathbf{Y}^{t+1} = \mathbf{J}(\vec{x}^t)\mathbf{Y}^{t}
#     = \mathbf{J}(\vec{x}^t) \cdot \mathbf{J}(\vec{x}^{t-1}) \cdot \cdots \cdot \mathbf{J}(\vec{x}^0)\mathbf{Y}^0,
# $$
#
# $$
#     \mathbf{Y}^{t+1} = \left(\prod_{\tau=0}^{t}  \mathbf{J}(\vec{x}^{t-\tau}) \right) \mathbf{Y}^0,
# $$
#
# where the matrix multiplication now is _not_ modulo 2! Given a graph and a LLNA, we can therefore calculate this $\mathbf{Y}^t$ from any initial configuration $\vec{x}_0$.

# %% [markdown]
# We are interested in eigenvalues of this matrix, so it is interesting to perform some kind of diagonalisation. We will not diagonalise $\textbf{Y}^t$ itself, but rather the matrix $\mathbf{\Gamma}^t$ (cf. Vispoel 2024), defined as
#
# $$
# \mathbf{\Gamma}^t = \mathbf{Y}^t \cdot (\mathbf{Y}^t)^{\text{T}}.
# $$
#
# To calculate the Lyapunov exponent within the tangent space, we extract the eigenvalues $\Lambda_i^t$ of $\mathbf{\Gamma}^t$, satisfying the equation $\mathbf{\Gamma}^t \vec{u}_i = \Lambda_i^t \vec{u}_i$, where $\vec{u}_i$ denotes the $i$-th eigenvector of $\mathbf{\Gamma}^t$. Note that due to the construction of $\mathbf{\Gamma}$, there will be $N$ real eigenvalues. The Lyapunov spectrum is defined as follows:
# $$
#     \Lambda_i = \lim_{t \rightarrow \infty}\frac{1}{t}\ln(\Lambda_i^t)
# $$
#
# where $\Lambda_i$ is the $i$-th Lyapunov exponent (to some extent answering the question "_what happens if we disturb node $x_i$?_"). All $N$ Lyapunov exponents are typically presented in a histogram. Now the limit will not necessarily go to zero, because the eigenvalues can grow limitlessly in the tangent space.
#
# <font color='green'>
#
# <b>Note</b> that in the context of uniform cellular automata it does not really matter which node (cell) is perturbed, because of the homogeneity of the system. For graphs, a distinction is to be made, however. This implies that it may be interesting to show the Lyapunov exponents in a particular order, rather than just plotting the histogram of all values.
#
# <b>Note</b> calculating the Lyapunov exponent in the tangent-space interpretation is not aided by calculating the difference patterns beforehand.
# </font>

# %% [markdown]
# <font color='purple'>The part from the old overview file goes until here. The following equation was already here when I started doing the merge with the lastupdates from Michiel.
#
# It seems to lack connection with the overall content, and also diverges with the equation presented in the above section "Lyapunov exponent on configuration space formalism".
#
# Am I missing something? Maybe its just another definition, or a correction of the aforementioned.</font>
#
# The Lyapunov exponent is defined by taking the limit of $\frac{1}{t}\log|\delta\vec{x}^t|$ when $t \rightarrow \infty$.

# %%
#Tangent space
def tangent_space(G, model, s0, s0_defect, T):
    #Allocating space
    N = len(s0)
    edges = G.get_edgelist()
    Js = np.zeros(shape=(T-1,N,N))
    states_original = np.tile(s0, (T,1))
    states_perturbed = np.tile(s0_defect, (T,1))
    deltas = np.tile(s0_defect, (T,1))
    for t in range(1,T):
        states_original[t] = np.array(model.step(tc.tensor(edges).T, tc.tensor(states_original[t-1])))
        states_perturbed[t] = np.array(model.step(tc.tensor(edges).T, tc.tensor(states_perturbed[t-1])))
        Js[t-1] = jacobian(G, model, states_original[t])
        deltas[t] = np.mod(np.matmul(Js[t-1], deltas[t-1]),2)
    #The Lyapunov exponent
    L = np.log(sum(deltas[t]))/T
    return L

# %% [markdown]
# **Relationship between damage spreading and the network diameter**

# %% [markdown]
# Considering a initial perturbation $\delta \vec{x}^0$ upon a subset of nodes, at step $t$, the nodes affected by perturbations form a subnetwork $G_{\Delta}^t \subseteq G$. Utilizing $G_{\Delta}^t$, we can determine the rate of spread of the variation pattern, denoted by $\gamma$ to a cellular automaton model on the network in the following manner:
#
# $$
#     \gamma (t) = \frac{1}{t}D(G^t_{\Delta})
# $$
# where $D(G^t_{\Delta})$ represents the diameter of the subnetwork affected by the spreading of perturbations.

# %% [markdown]
# **Interpretation of both formalisms**

# %% [markdown]
# In configuration space, the Lyapunov exponent indicates how quickly small initial differences between two states will grow. A positive Lyapunov exponent suggests that small perturbations will lead to significant divergence over time, indicating chaotic behavior. Conversely, a negative exponent implies that perturbations will die out, leading to stable behavior.
#
# In tangent space, the Lyapunov exponent provides a more detailed picture of the system's stability by quantifying the exponential rates at which small perturbations in various directions grow or shrink. This approach offers a finer resolution of the system's dynamics, capturing the behavior of individual perturbations and their interactions over time. The spectrum of Lyapunov exponents from tangent space analysis can reveal the presence of chaotic dynamics even if the configuration space does not exhibit exponential growth directly.
#
# In summary, while both spaces offer insights into the stability and dynamics of CA, the configuration space gives a more global view of the system's behavior under perturbations, and the tangent space provides a detailed, linearized analysis of how these perturbations evolve. The Lyapunov exponents in tangent space, being derived from a linearized model, can reveal intricate details about the system's stability and chaotic nature that might not be apparent from the configuration space alone.

# %% [markdown]
# ## 1.3 - Example of the Lyapunov exponent in a toy NA
#
# Below we construct a very simple NA and a very simple Jacobian.

# %%
# a simple network
N = 20
min_edges = 2
Gs = [ig.Graph.Barabasi(N, min_edges) for _ in range(5)]

vertex_size=10
fig, axs = plt.subplots(2,5,figsize=(12,4))
for G, ax_top, ax_bottom in zip(Gs, axs[0], axs[1]):
    ig.plot(G, target=ax_top, vertex_size=vertex_size)
    A = np.array([ *G.get_adjacency() ])
    ax_bottom.imshow(A, cmap='Greys')
    ax_bottom.set_xticks([])#range(N))
    ax_bottom.set_yticks([])#range(N))
    ax_bottom.tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)

G = Gs[-1]
G.to_directed()
edges = tc.tensor(G.get_edgelist()).T
G.to_undirected()

_=fig.suptitle("A couple of very simple Barabási-Albert graphs with their adjacency matrices. We will continue with the last one.")

# %% [markdown]
# Note that in this example, none of the nodes are connected to themselves. **QUESTION** is this OK? I guess it is, because the LLNA rule definitions involve the current state of the node (cf. the double curve).

# %%
def step_inspector(matrices:dict):
    for name in ['h', 'p', 'b', 's']:
        M = np.array(matrices[name]).round(decimals=2)
        print(f'{name}:', M.shape, M)
    print('-'*40)

def plot_params(graph, labels=False):
    import math
    params = {
        'vertex_color': np.array(graph.vs["states"])*255,
        'edge_color': 125,
        'vertex_size': 10
    }
    if labels:
        params.update({
            'vertex_label': graph.vs["name"],
            'vertex_label_color': 'blue',
            'vertex_label_size': 10,
            'vertex_label_dist': 1.5,
            'vertex_label_angle': math.pi/4
        })
    return params

# %%
# a simple LLNA
resolution = 2
model = LLNA(resolution) # takes a random LLNA at this resolution
#model.rule = ([0], [0]) # specify the rule B0_S0
#model.callback = step_inspector # callback to be executed at each automaton step
rule = str(model)

# random initial condition
s0 = np.random.randint(2, size=N).astype(float)
#s0 = np.array([0,1,0,0,0,1]).astype(float) # specify the initial state
# perturbation on first node
s0_defect = s0.copy()
s0_defect[0] = 1-s0_defect[0]

# open figure
fig, axs = plt.subplots(2,5,figsize=(12,4))
size=10

G.vs["states"] = s0
G.vs["name"] = [ f'v{i}' for i in range(N) ]
ig.plot(G, target=axs[0,0], **plot_params(G, labels=False))
axs[0,0].set_title("Init. config.", size=size)

# assign to state property of graph
# turn configuration into tc tensor and add extra dimension for number of samples
st = tc.tensor(s0)[None,:]
for t, ax in enumerate(axs[0,1:]):
    # evolve over one time step
    st = model.step(edges, st)
    G.vs["states"] = np.array(st[0])
    ig.plot(G, target=ax, **plot_params(G, labels=False))
    ax.set_title(f"t={t+1}", size=size)

# rinse and repeat for defected graph
G.vs["states"] = s0_defect
G.vs["name"] = [ f'$\\Delta v{i}$' for i in range(N) ]
ig.plot(G, target=axs[1,0], **plot_params(G, labels=False))
axs[1,0].set_title("Init. config. (defect)", size=size)

st = tc.tensor(s0_defect)[None,:]
for t, ax in enumerate(axs[1,1:]):
    # evolve over one time step
    st = model.step(edges, st)
    G.vs["states"] = np.array(st[0])
    ig.plot(G, target=ax, **plot_params(G, labels=False))
    ax.set_title(f"t={t+1}", size=size)

_=fig.suptitle(f"Subsequent states for rule {rule}, from original (top) and defected (bottom) configuration.")

# %% [markdown]
# **NOTE** in the representation above, white signifies "alive", and black signifies "dead".

# %% [markdown]
# Next, we calculate the Jacobian for this particular network and for initial configuration $\vec{s}_0$. Recall that the elements of the Jacobian are defined by
# $$
# J_{ij}(\vec{x}^{t}) = F_i(\vec{x}^t) \oplus F_i(\vec{x}^t \oplus \delta\vec{x}_j),
# $$
# where $i$ counts the rows and $j$ counts the columns. Let's define this for a single time step:

# %%
# def jacobian(graph, model, states, return_next=False):
#     ### returns Jacobian matrix with dimensions N x N, where N is the number of nodes in the graph
#     # number of nodes
#     N = len(states)
#     states = states.astype(int)

#     # get ID of edges (bidirectional)
#     graph.to_directed()
#     edges = tc.tensor(graph.get_edgelist()).T
#     graph.to_undirected()

#     # make matrix with N rows of the same state array
#     states_all = np.tile(states, (N,1))
#     # calculate unperturbed next-timestep state vector (N times in parallel)
#     states_all_next = np.array(model.step(edges, tc.tensor(states_all)), dtype=int)

#     # make matrix with all possible single-defect perturbations
#     states_defect_all = (np.tile(states, (N,1)) + np.diag(np.ones(N, dtype=int))) % 2
#     # calculate perturbed next-timestep state vector (N times in parallel)
#     states_defect_all_next = np.array(model.step(edges, tc.tensor(states_defect_all)), dtype=int)

#     # compile Jacobian with XOR operator (the Boolean derivative)
#     J = (states_all_next + states_defect_all_next) % 2

#     # return transpose (to match definition)
#     if return_next:
#         return J.T, states_all_next[0]
#     return J.T

# note that the Jacobian will depend on the initial state!
states = np.random.randint(2,size=N)

### verify that Jacobian definition is correct
# defect in j'th column
defect = np.zeros(N, dtype=int)
j = N//3
defect[j] = 1
states_def = (states + defect) % 2

# get ID of edges (bidirectional)
G.to_directed()
edges = tc.tensor(G.get_edgelist()).T
G.to_undirected()

states_next = np.array(model.step(edges, tc.tensor(states)), dtype=int)
states_def_next = np.array(model.step(edges, tc.tensor(states_def)), dtype=int)
defect_next = (states_next + states_def_next) % 2

J = jacobian(G, model, states)

# all entries in the j'th column correspond
(J[:,j] == defect_next).all()

# %% [markdown]
# This definition is correct. There is one important subtlety, though! So let's say that we start off with a defect in node 0, which is represented as $\delta \vec{x}^0_0 = (1, 0, \ldots, 0)$, we can use the Jacobian to calculate the defect in the next time step:
# $$
# \delta\vec{x}^{1} = J(\vec{x}^0) \otimes \delta\vec{x}^0,
# $$
# because that is precisely how the Jacobian is defined. However, when tracing the evolution of this defect, nonlinearities will arise and
# $$
# \delta \vec{x}^{t+1} = J(\vec{x}^t)\delta\vec{x}^t = J(\vec{x}^t)J(\vec{x}^{t-1}) \ldots J(\vec{x}^0)\delta\vec{x}^0.
# $$
# will not generally hold. In other words,
# $$
# F^t_i(\vec{x}^0) \oplus F^t_i(\vec{x}^0 \oplus \delta\vec{x}^0_i) \neq \delta\vec{x}^{t}_i,
# $$
# because this 'defect term' only has an interesting meaning in tangent space, not in configuration space. Let's verify this visually for four time steps.

# %%
T = 5

# imposed defect in a particular node
defect_pos = 0
delta_x0 = np.zeros(N, dtype=int)
delta_x0[defect_pos] = 1

# initial configuration
states = np.random.randint(2,size=N)

# allocate all T-1 Jacobians
Js = np.zeros(shape=(T-1,N,N), dtype=int)
# all states (will be updated in the loop)
states_original = np.tile(states, (T,1))
states_perturbed = np.tile((states+delta_x0)%2, (T,1))
deltas = np.tile(delta_x0, (T,1))

# iterate original NA, perturbed NA, and the defect itself over T time steps
for t in range(1,T):
    # calculate next time step (from unperturbed initial configuration)
    states_original[t] = np.array(model.step(edges, tc.tensor(states_original[t-1])))
    # calculate next time step (from perturbed initial configuration)
    states_perturbed[t] = np.array(model.step(edges, tc.tensor(states_perturbed[t-1])))
    # calculate Jacobian Js[t-1] for switching from time step t-1 to t.
    Js[t-1] = jacobian(G, model, states_original[t-1])
    # new defect term. This should work for one time step, but generally diverge afterwards
    deltas[t] = np.mod(np.matmul(Js[t-1], deltas[t-1]),2)

fig, axs = plt.subplots(3,T,figsize=(12,6))
size=10

for row in range(3):
    colors = [states_original, states_perturbed, deltas][row]
    for t, ax in enumerate(axs[row,:]):
        if row == 2:
            vertex_color = [(1, 1-colors[t,v], 1-colors[t,v]) for v in range(N)]
        else:
            vertex_color = colors[t]*255
        ig.plot(G, target=ax, vertex_color=vertex_color, vertex_size=10)
        ax.set_title(f"t={t}", size=size)

_=fig.suptitle(f"Subsequent states for rule {rule}, from original (top) and defected (bottom) configuration.")

# %% [markdown]
# Note that the general observation is correct as well: the definition works for one time step, but diverges afterwards because of non-linearities caused by multiple changes within the same neighbourhood.
#
# **NOTE** I could add an illustration for the tangent-space evolution (showing how certain nodes grow 'darker and darker').

# %% [markdown]
# <hr>

# %% [markdown]
# # 2 - Methods

# %% [markdown]
# ## 2.1 - Graph setup

# %% [markdown]
# Given a complex network model $\mathcal{M}$, a number of samples (graphs) per model $N_\text{samples}$, a number of nodes per graph $N_\text{nodes} = |V|$ and a number of initial configurations per sample $N_\text{init}$, we generate a set of graphs $\mathcal{G}^\mathcal{M} = \{ G(\mathbf{A}, \mathbf{S}_0) \}$, where $\mathbf{A} \in\ \{0;1\}^{N_\text{nodes} \times N_\text{nodes}}$ is the adjacency matrix, $\mathbf{S}_0 = [\vec{s}_0] \in \mathbb{S}^{N_\text{init} \times N_\text{nodes}}$ is the node's state matrix at the initial step $t = 0$ and the cardinality of the set is $\left| \mathcal{G}^\mathcal{M} \right| = N_\text{samples}$.

# %% [markdown]
# The state vector can be evolved at discrete time steps by applying the automaton, $\vec{s}_{t+1} = \mathcal{C}(\vec{s}_{t}) \in \mathbb{S}^{|V|}$. Similarly, in matricial notation, we can evolve multiple $L$ state configurations (like original and disturbed setups) by $\mathbf{S}_{t+1} = \mathcal{C}(\mathbf{S}_{t}) \in \mathbb{S}^{L \times |V|}$. Then, we can generalize the time evolution pattern matrix in terms of $\mathbf{S}$ to acomodate any number of $L$ simultaneously simulated scenarios, like $\mathbf{H} \in \mathbb{S}^{L \times |V| \times T}$.

# %% [markdown]
# As we are interested in assess how initial perturbations (disturbs) propagate through the network given an automaton, the number $L$ will denote the inicial configuration plus $|V|$ unitary perturbations (one at each node), so $L = 1 + |V|$ when doing an exhaustive experiment. It's also possible to randomly sample a subset of nodes $\tilde{V} \subset V$ to disturb and, by ensuring $|\tilde{V}| \ll |V|$, reduce drasticaly the computational cost to $L = 1 + |\tilde{V}|$ scenarios per automaton.

# %%
dataset = NetworksDataset(path='data/graphs', cached=False)

# %%
E, h0 = dataset[10]
E.shape, h0.shape

# %%
automaton = LLNA(resolution=4, x=[1,3], y=[0,2])
str(automaton)

# %%
# for each initial condition, create a set of N orthogonal perturbations
# and append to the original init. cond.
H0 = tc.stack([ orth_disturbs(h, True) for h in h0 ], 0)
print(H0.shape)

# join together the first two dimensions
H0 = prepare_shape(H0)
print(H0.shape)

# run the automaton
H = automaton(E, H0, T=3)
print(H.shape)

# separate the first dimension in two
H = restore_shape(H)
print(H.shape)

# %%
# check if the initial condition vectors are in the desired place
for i, hi in enumerate(h0):
    print(~(hi != H[i, 0, 0]).any())

# %% [markdown]
# ## 2.2 - Network automata rules

# %%
for R in range(2,4):
    for i, (X,Y) in enumerate(all_rules_from(R, 2)):
        automaton = LLNA(R, X, Y)
        print(f'[#{i+1:03d}] ', str(automaton))
    print()

# %% [markdown]
# ## 2.3 - Time-evolution patterns and graph centrality measures

# %% [markdown]
# By evolving an NA over a graph, we may collect the dynamics of the states of the nodes, i.e. all $\vec{s}_{t}$, in a so-called time-evolution pattern (TEP). This is a two-dimensional representation of the NA that is highly reminiscent of a spacetime diagram for a cellular automaton. The difference, however, is that a graph does not impose a regular spatial structure between its nodes. This implies that one needs to make a choice regarding how to order the nodes from left to right in the TEP. A clever choice of this ordering will increase the possibility of discerning patterns hidden within the dynamics of the NA.
#
# Several choices present themselves, and all are related to particular properties of the nodes. Graph theory (and graph packages in Python, for that matter) suggests a number of possibilities.
#
# See also: https://igraph.org/python/tutorial/0.9.6/analysis.html#vertex-properties. Below is a list of all these methods.
#
# See also: https://www.turing.com/kb/graph-centrality-measures
#
# Also, see Michiel's interaction log with ChatGPT.

# %% [markdown]
# ### _Node degree_
#
# We can of course simply order the nodes from left to right, starting with nodes that have the highest number of neighbours. Because the degree $d \in \mathbb{N}$, the set of all possible degrees in the network is typically not very large. This means that the ordering of these nodes is typically not fully determined by inspecting the node degrees.

# %%
# for example: node degree
N=25; p=.2
G = ig.Graph.Erdos_Renyi(n=N, p=p)

fig, ax = plt.subplots(1,1,figsize=(4,3))

degrees = G.degree()
min_degree = min(degrees); max_degree = max(degrees)
bins = np.arange(min_degree, max_degree+2)-.5

ax.hist(degrees, bins=bins)
ax.set_xlim(min_degree-1.5, max_degree+1.5)
ax.set_xticks(bins[:-1]+.5)

ax.set_xlabel("Node degree")
ax.set_ylabel("Number of nodes")
ax.set_title(f"Node degree distribution for $N={N}$")

# %% [markdown]
# ### _PageRank_
#
# This is a type of eigenvector centrality, and takes into account not only the importance of a single node, but also the importance of the surrounding nodes.
#
# The PageRank values of the nodes in a graph were first defined by Larry Page to quantify the importance of a website. It is mathematically (and recursively) defined as
# $$
# PR(x_i) = \sum_{x_j \in \mathcal{N}(x_i)} \frac{PR(x_j)}{|\mathcal{N}(x_j)|},
# $$
# where $\mathcal{N}(x_i)$ represents the neighbourhood of node $x_i$, excluding $x_i$ itself. Note that for a fully-connected network consisting of $N$ nodes, this results in a PageRank of $1/N$ for each node.
#
# One practical advantage of using PageRank is that it is very likely to assign a unique value to each node, even for graphs that are close to regular. One theoretical advantage is that 'the likelikehood to end up on a webpage' or the 'relevance of a webpage' may be an important indicator for how important this node is for the robustness of our entire NA. In other words, this is a good candidate for ordering our TEP.

# %%
# for example: PageRank
N=1000; p=0.2
G = ig.Graph.Erdos_Renyi(n=N, p=p)

fig, ax = plt.subplots(1,1,figsize=(4,3))

PageRank = G.pagerank()
PageRank_unique = len(np.unique(np.array(PageRank)))

bins=20 # None
ax.hist(PageRank,bins=bins)

ax.set_xlabel("PageRank")
ax.set_ylabel("Number of nodes")
ax.set_title(f"PageRank distribution for $N={N}$\nContains {PageRank_unique} unique values")

# %% [markdown]
# ### _Closeness_
#
# Probably relevant as well: "Closeness centrality finds application in identifying individuals that are in a position to influence the entire network in the fastest way possible." (turing.com)
#
# "Closeness was defined by Bavelas (1950) as the reciprocal of the farness" (Wikipedia), so, normalised over the number of nodes, we get
# $$
# C(x_i) = (N-1)\left(\sum_{0 \leq j < N}d(x_i, x_j)\right)^{-1},
# $$
# where $d(x_i, x_j)$ is the shortest path between nodes $x_i$ and $x_j$. A fully-connected graph therefore has a closeness of 1 for each nodes.
#
# Due to the nature of its construction, this measure will not generate unique values for all nodes, which may be an issue when using this for ordering the nodes in a TEP.
#
# A variation on the closeness is the harmonic centrality, which has received less attention in academia. Mathematically, it is simply a matter of changing the order of the sum and inversion operators (and normalising accordingly):
# $$
# H(x_i) = \frac{1}{N-1}\sum_{0 \leq j < N}\left(\frac{1}{d(x_i, x_j)}\right).
# $$

# %%
# example: closeness and harmonic centrality
N=1000; p=0.2
G = ig.Graph.Erdos_Renyi(n=N, p=p)

fig, axs = plt.subplots(1,2,figsize=(9,3), sharey=True)

closeness = G.closeness(normalized=True)
closeness_unique = len(np.unique(np.array(closeness)))
harmonic = G.harmonic_centrality(normalized=True)
harmonic_unique = len(np.unique(np.array(harmonic)))

bins=20 # None

axs[0].hist(closeness,bins=bins)
axs[1].hist(harmonic,bins=bins)

axs[0].set_xlabel("Normalised closeness")
axs[0].set_ylabel("Number of nodes")
axs[0].set_title(f"Closeness distribution for $N={N}$\nContains {closeness_unique} unique values")

axs[1].set_xlabel("Normalised harmonic centrality")
axs[1].set_title(f"harmonic centrality distribution for $N={N}$\nContains {closeness_unique} unique values")

# %%
# correlation between harmonic centrality and closeness
fig, ax = plt.subplots(1,1,figsize=(4,3))

PearsonR = np.corrcoef(closeness, harmonic)[0,1]**2

ax.scatter(closeness, harmonic, s=1, alpha=.5)

ax.set_xlabel("Closeness")
ax.set_ylabel("Harmonic centrality")
ax.set_title(f"Harmonic centrality vs. Closeness\n$R^2$: {round(PearsonR,5)}")

# %% [markdown]
# In other words, we can choose the measure that we like most, as they are virtually identical.

# %% [markdown]
# ### _Betweenness_
#
# "Measure for the number of shortest paths that pass through a node. Nodes with high betweenness centrality are critical for information flow. Their stability can enhance the overall robustness of the network." (ChatGPT)
#
# Mathematically, betweenness is calculated as follows:
# $$
# g(x_i) = \sum_{j\neq i}\sum_{k\neq i}\frac{\sigma_{jk}(x_i)}{\sigma_{jk}},
# $$
# where $\sigma_{jk}$ is the _total_ number of shortest paths from node $x_j$ to $x_k$, and $\sigma_{jk}(x_i)$ is the number of those paths that pass through node $x_i$. Note that the sum only goes over nodes that are not identical to $x_i$, so the shortest paths can never end in $x_i$.
#
# Interestingly, betweenness is (typically) a unique value per node, so ordering would be straightforward.

# %%
# example: betweenness
N=1000; p=0.2
G = ig.Graph.Erdos_Renyi(n=N, p=p)

fig, ax = plt.subplots(1,1,figsize=(4,3))

betweenness = G.betweenness(directed=False)
betweenness_unique = len(np.unique(np.array(betweenness)))

bins=20 # None
ax.hist(betweenness,bins=bins)

ax.set_xlabel("Betweenness")
ax.set_ylabel("Number of nodes")
ax.set_title(f"Betweenness distribution for $N={N}$\nContains {betweenness_unique} unique values")

# %% [markdown]
# Considering that betweenness and PageRank both generate unique values per node, both are interesting for finding a unique node ordering. Let's inspect whether these quantities are related to each other in a simple scatter plot.

# %%
# comparing betweenness and PageRank
N=1000; p=0.2
G = ig.Graph.Erdos_Renyi(n=N, p=p)

fig, ax = plt.subplots(1,1,figsize=(4,3))

PageRank = G.pagerank()
betweenness = G.betweenness(directed=False)
PearsonR = np.corrcoef(PageRank, betweenness)[0,1]**2

ax.scatter(PageRank, betweenness, s=1, alpha=.5)

ax.set_xlabel("PageRank")
ax.set_ylabel("Betweenness")
ax.set_title(f"Betweenness vs. PageRank. $R^2$: {round(PearsonR,2)}")

# %% [markdown]
# Clearly, these are highly correlated.

# %% [markdown]
# ### _Clustering coefficient_
#
# Also known as transitivity.
#
# "A measure of the degree to which nodes in a graph tend to cluster together.
# High clustering can enhance local robustness, as tightly-knit clusters may stabilize each other." (ChatGPT)
#
# This measure is particularly relevant for Watts-Strogatz graphs (and they came up with it). The centrality of node $x_i$ is defined as (Wikipedia)
# $$
# C_i = \frac{2|\{e_{jk} : x_j, x_k \in \mathcal{N}(x_i), e_{jk} \in E\}|}{|\mathcal{N}(x_i)||\mathcal{N}(x_i)-1|},
# $$
# where $\mathcal{N}(x_i)$ is the neighbourhood of node $x_i$ excluding node $x_i$ itself (more simply put: $|\mathcal{x_i}|$ is simply the degree of node $x_i$). This is identical to saying that
# $$
# C_i = \frac{\lambda_G(x_i)}{\tau_G(x_i)},
# $$
# where $\lambda_G(x_i)$ is the number of triangles on $x_i$, and $\tau_G(x_i)$ is the number of triples on $x_i$. Note that, because $\tau_G(x_i) \geq \lambda_G(x_i)$, $C_i$ is always between 0 and 1.

# %%
# example: clustering
N=1000
ps=[0.49, 0.5, 0.51]
Gs = []

for p in ps:
    G = ig.Graph.Erdos_Renyi(n=N, p=p)
    Gs.append(G)

fig, ax = plt.subplots(1,1,figsize=(5,3))
bins=20 # None

for p, G in zip(ps,Gs):
    clustering = G.transitivity_local_undirected()
    clustering_unique = len(np.unique(np.array(clustering)))
    ax.hist(clustering,bins=bins, label=f"p = {p}")

ax.set_xlabel("Clustering coefficient")
ax.set_ylabel("Number of nodes")
ax.set_title(f"Clustering coefficient for $N={N}$\nContains {betweenness_unique} unique values per graph")
plt.legend(ncols=3)

# %% [markdown]
# Note that a higher rewiring probability (parameter `p`) generates higher clustering coefficients. Generally, the higher the number of nodes $N$, the more clearly the clustering coefficient distributions will be separated. In addition, note that again all clustering values are unique, which is desired for the ordering of our nodes in the TEP.

# %% [markdown]
# ### _Similarity measures_
#
# We can compare a node with all other nodes and give a score which quantifies how 'similar' they are, with some well-defined notion of similarity. This results in a similarity matrix $\Sigma$ with elements $\Sigma_{ij}$ for $0 \leq i,j < N$. The `igraph` package provides three variations:
#
# 1. _Jaccard similarity_: The Jaccard similarity coefficient of two vertices is the number of their common neighbors divided by the number of vertices that are adjacent to at least one of them.
#
# 2. _Dice similarity_: The Dice similarity coefficient of two vertices is twice the number of their common neighbors divided by the sum of their degrees. This
# coefficient is very similar to the Jaccard coefficient, but usually gives higher similarities than its counterpart.
#
# 3. _Inverse log-weighted similarity_: Each vertex is assigned a weight which is 1 / log(degree). The log-weighted similarity of two vertices is the sum of the weights of their common neighbors.
#
# Clearly, these measures generate a _vector_ per node, which is perhaps not ideal for ordering the nodes. But they are briefly investigated below regardless.

# %%
# for example: similarity measures
import igraph as ig
import matplotlib.pyplot as plt

N=25; p=.2
G = ig.Graph.Erdos_Renyi(n=N, p=p)

fig, axs = plt.subplots(1,3,figsize=(9,3))

jacc_sim = G.similarity_jaccard()
dice_sim = G.similarity_dice()
inverse_log = G.similarity_inverse_log_weighted()

im=axs[0].imshow(jacc_sim)
axs[1].imshow(dice_sim)
axs[2].imshow(inverse_log)

axs[0].set_title(f"Jaccard Similarity")
axs[1].set_title(f"Dice Similarity")
axs[2].set_title(f"Inverse log-\nweighted Similarity")

fig.colorbar(im, ax=axs.ravel().tolist())

# %% [markdown]
# ## 2.4 - Assessing robustness by means of the Lyapunov spectrum
#
# ### _Configuration space interpretation_
#
# In the case of the configuration-space interpretation of the Lyapunov exponent for networks, we can define
# $$
# \gamma(t) = \frac{1}{t}D(\mathcal{G}_\Delta^t),
# $$
# where $D$ denotes the diameter of the subnetwork consisting of all the nodes that have been perturbed at least once after $t$ time steps. The diameter of a network is defined as the shortest path between the two most distant nodes:
# $$
# D(\mathcal{G}_\Delta^t) = \max_{u,v \in \mathcal{G}_\Delta^t} d(u,v),
# $$
# where $d(u,v)$ represents the shortes path between nodes $u$ and $v$. The diameter of a subgraph can be larger than the diameter of the graph that it is a part of, because some links may be missing. As a sidenote: determining the subgraph with the largest diameter is NP-complete.
#
# ![image.png](attachment:image.png)
#
# Note that for finite graphs, this value $\gamma(t)$ will always go to zero in the large-$t$ limit, so we need to find a reasonable cut-off value.
#
# Consider again our toy model:

# %%
T = 5
N = 10

resolution = 2
model = LLNA(resolution) # takes a random LLNA at this resolution
rule = model.__str__()

p=.3
G = ig.Graph.Erdos_Renyi(n=N, p=p)
G.to_directed()
edges = tc.tensor(G.get_edgelist()).T
G.to_undirected()

# imposed defect in a particular node
defect_pos = 0
delta_x0 = np.zeros(N, dtype=int)
delta_x0[defect_pos] = 1

# initial configuration
states = np.random.randint(2,size=N)

# all states (will be updated in the loop)
states_original = np.tile(states, (T,1))
states_perturbed = np.tile((states+delta_x0)%2, (T,1))
deltas = np.tile(delta_x0, (T,1))

# iterate original NA, perturbed NA, and the defect itself over T time steps
for t in range(1,T):
    # calculate next time step (from unperturbed initial configuration)
    states_original[t] = np.array(model.step(edges, tc.tensor(states_original[t-1])))
    # calculate next time step (from perturbed initial configuration)
    states_perturbed[t] = np.array(model.step(edges, tc.tensor(states_perturbed[t-1])))
    # new defect term. This should work for one time step, but generally diverge afterwards
    deltas[t] = (states_original[t] + states_perturbed[t]) % 2

fig, axs = plt.subplots(3,T,figsize=(12,6))
size=10

for row in range(3):
    colors = [states_original, states_perturbed, deltas][row]
    for t, ax in enumerate(axs[row,:]):
        if row == 2:
            vertex_color = [(1, 1-colors[t,v], 1-colors[t,v]) for v in range(N)]
        else:
            vertex_color = colors[t]*255
        ig.plot(G, target=ax, vertex_color=vertex_color, vertex_size=10)
        ax.set_title(f"t={t}", size=size)

_=fig.suptitle(f"Subsequent states for rule {rule}, from original (top) and defected (bottom) configuration.")

# %% [markdown]
# Now, here the bottom row depicts the *factual* defect (not the defect in tangent space calculated from the Jacobian). We can also show the subgraph of all nodes that *have been* affected, which would look a little something like ...

# %%
deltas_cum = np.cumsum(deltas, axis=0)
deltas_cum = np.clip(deltas_cum, 0, 1)

fig, axs = plt.subplots(1,T,figsize=(12,2.5))
size=10

for t, ax in enumerate(axs):
    subG = G.subgraph(np.where(deltas_cum[t])[0])
    diam = subG.diameter()
    ig.plot(subG, target=ax, vertex_size=10)
    ax.set_title(f"Diameter: {diam}", size=size)

# %% [markdown]
# Translating this to a general formula, we find ...

# %%
# show some examples
T = 5
N = 10
states = np.random.randint(2, size=N, dtype=int)

# imposed defect in a particular node
defect_indices = [0, N//2, N-1]

# get ID of edges (bidirectional)
G.to_directed()
edges = tc.tensor(G.get_edgelist()).T
G.to_undirected()

# parallellise all possible defects
states_original = np.tile(states, (N,1))
states_perturbed = (states_original + np.diag(np.ones(N, dtype=int))) % 2
# dimensions of states: [defect_index, time, node]
states_original = np.array(model.forward(edges, tc.tensor(states_original), T=T), dtype=int)
states_perturbed = np.array(model.forward(edges, tc.tensor(states_perturbed), T=T), dtype=int)

# find defects and indicate nodes with a defect history with a 1
deltas = (states_original + states_perturbed) % 2
deltas_cum = np.cumsum(deltas, axis=1)
deltas_cum = np.clip(deltas_cum, 0, 1)

# calculate diameters (transpose to follow conventions)
diameters = np.array([defect_diameter(G, model, states, t, norm=False) for t in range(T+1)]).T

# open figure
fig, axs = plt.subplots(len(defect_indices),T+1,figsize=(12,6))
size=10

# plot defect spreading into subgraphs
for row, defect_index in enumerate(defect_indices):
    axs[row,0].set_ylabel(f"Defect node: {defect_index}")
    for t, ax in enumerate(axs[row,:]):
        vertex_color = 255-deltas_cum[defect_index, t]*255
        ig.plot(G, target=ax, vertex_color=vertex_color, vertex_size=10)
        diameter = diameters[defect_index, t]
        ax.set_title(f"Diameter {diameter}")

_=fig.suptitle(f"Cumulative damage spreading into subgraphs of G (diameter {G.diameter()}).", size=size+6)

# %%
# Let's look at what happens for long stretches of time

N_samples = 200
Ts = np.arange(1,16)

import matplotlib.cm as cm
import matplotlib.colors as mcolors
cmap = cm.inferno
colors = cmap(np.linspace(0, 1, N))

fig, ax = plt.subplots(1,1, figsize=(12,5))

diameters_samples = []
for sample in range(N_samples):
    if sample % 10 == 0:
        print(f"Processed {sample}/{N_samples} samples.", end='\r')
    states = np.random.randint(2, size=N, dtype=int)
    diameters = np.array([defect_diameter(G, model, states, T, norm=False) for T in Ts]).T
    diameters_samples += [diameters]
diameters_samples = np.array(diameters_samples, dtype=int)

diameters_stds = np.std(diameters_samples, axis=0)
diameters_means = np.mean(diameters_samples, axis=0)

for defect_index in range(N):
    upper = diameters_means[defect_index] + diameters_stds[defect_index]
    lower = diameters_means[defect_index] - diameters_stds[defect_index]
    ax.fill_between(Ts, lower, upper, color=colors[defect_index], alpha=.1)
    ax.plot(Ts, diameters_means[defect_index], color=colors[defect_index], ls='--', lw=2)
diam_original = G.diameter()

ax.plot(Ts, np.ones_like(Ts)*diam_original, 'k.-', label='Diameter of full graph')
ax.legend()
# ax.text(Ts[-1]*.7, diam_original+.05, "Diameter of full graph")

# ax.legend(title="Defect in ...", ncols=2, loc='center right', bbox_to_anchor=(1.5,.5))
ax.set_xlabel(f"Number of time steps $T$")
ax.set_ylabel(f"Diameter of affected subgraph (mean $\pm1$ sigma)")

norm = mcolors.Normalize(vmin=0, vmax=N-1)
sm = cm.ScalarMappable(cmap='inferno', norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, label='Defected Node')
cbar.set_ticks(np.arange(N)[1::2])

_=fig.suptitle(f"Graph with {N} nodes, rule {rule}, averaged over {N_samples} initial configurations")

# %% [markdown]
# Note here that, indeed, the diameter of the affected subgraph can be larger than the diameter of the full graph. In other words: just looking at the diameter is not sufficient for gauging whether the defect has spread efficiently.
#
# **QUESTION** Are there any other distance measures of the defect subgraph that could be more informative?
# - Number of vertices or number of edges
# - Average path length
# - Graph density (indicates how close the graph is to being a complete graph)
# - Graph radius (but this is quite similar to graph diameter)
# - Edge / vertex connectivity: the minimum number of edges/vertices that need to be removed in order to disconnect the remaining graph

# %% [markdown]
# ## _Tangent space interpretation_
#
# From the Jacobian, we define the Lyapunov spectrum:
# $$
# \lambda_i = \lim_{t\rightarrow\infty}\frac{1}{2t}\ln\Lambda_i^t,
# $$
# where the $\Lambda_i^t$ are the eigenvalues associated to the equation
# $$
# \langle \mathbf{Y}^t \vec{x}_i, \mathbf{Y}^t \vec{x}_i \rangle = (\Lambda^t_i)^2 \langle \vec{x}_i, \vec{x}_i \rangle.
# $$
# Therefore we need to calculate the eigenvalues of the matrix $\mathbf{Y}^t \left(\mathbf{Y}^t\right)^\text{T}$
#
# This still does not feel quite intuitive, so let us first do a sanity check, in which we find the Lyapunov spectrum of an ECA. In an ECA with periodic boundary conditions, we have a fully regular graph. The LLNA on such a regular graph is identified with an ECA on a ring graph, provided that the ECA makes no distinction between left and right, which is the case for all rules $W = (b_7 b_6 b_5 b_4 b_3 b_2 b_1 b_0)_2$, where
# $$
# \begin{cases}
#     b_6 = b_3,\\
#     b_4 = b_1.
# \end{cases}
# $$
# This leaves $2^{8-2} = 2^6 = 64$ rules of the $256$ elementary rules available. Let's code this up.

# %%
def ECA_to_LLNA(rule:int) -> LLNA:
    rule_bin = format(rule, '08b')
    # error if rule is not symmetric
    if (rule_bin[1] != rule_bin[4]) or (rule_bin[3] != rule_bin[6]):
        raise Exception(f"Elementary rule {rule} is not symmetric and cannot be converted to an LLNA.")
    # a cell can have 0, 1, or 2 live neighbours
    resolution = 3
    # cells are born when they used to be dead
    x=[]
    if int(rule_bin[7]):
        x.append(0)
    if int(rule_bin[3]): # equivalent to rule_bin[6]
        x.append(1)
    if int(rule_bin[2]):
        x.append(2)
    # cells survive when they used to be alive
    y=[]
    if int(rule_bin[5]):
        y.append(0)
    if int(rule_bin[1]): # equivalent to rule_bin[4]
        y.append(1)
    if int(rule_bin[0]):
        y.append(2)
    model = LLNA(resolution, x=x, y=y)
    return model

rule = 150 # np.random.randint(256)
ECA_as_LLNA = ECA_to_LLNA(rule)

N = 101
G_regular = ig.Graph.Ring(N)
# get ID of edges (bidirectional)
G_regular.to_directed()
edges = tc.tensor(G_regular.get_edgelist()).T
G_regular.to_undirected()

T = N//2
# states = tc.tensor(np.random.randint(2, size=(1,N)))
states_seed = np.zeros(N)
states_seed[N//2] = 1
H = ECA_as_LLNA.forward(edges, tc.tensor(states_seed[np.newaxis,:]), T=T)
H = np.array(H, dtype=int)

fig, axs = plt.subplots(1,2,figsize=(10,4))
ig.plot(G_regular,target=axs[0], vertex_size=10)
axs[1].imshow(H[0], cmap='Greys')
axs[1].set_title(f"Rule {rule} emulated in a ring network")
axs[1].set_xlabel("Nodes in the ring network")
axs[1].set_ylabel("Time steps")

# %%
ECA_as_LLNA.diagram()

# %% [markdown]
# That behaves as expected: we have simulated the ECA on an LLNA running on a graph neural network. Now, let's calculate some Lyapunov spectra for these ECAs to verify that that function behaves regularly as well. First, take the values from Milan's paper: N=101, T=50 (trying to reproduce fig. 14)

# %%
print(f"Rule {rule}\n")

samples = 100
T = N // 2

lambdas_all = np.array([])
nan_all = 0

for sample in range(samples):
    print(f"Working on sample {sample} ...", end='\r')
    states = np.random.randint(2,size=N)
    Yt = calculate_Yt(G_regular, ECA_as_LLNA, states, T)
    lambdas = lyapunov_spectrum(Yt, T)
    nan_all += len(lambdas[np.isnan(lambdas)])
    lambdas = lambdas[np.isfinite(lambdas)]
    lambdas_all = np.append(lambdas_all, lambdas, axis=0)
percentage_shown = round((1 - nan_all/N/samples)*100, 2)

fig, ax = plt.subplots(1,1,figsize=(8, 3))
ax.hist(lambdas_all, bins=25)
increment = N*samples/8
yticks = np.arange(0, N*samples/2+increment, increment)
ax.set_yticks(yticks)
ax.set_yticklabels(np.linspace(0, .5, len(yticks))*100)
ax.set_title(f"Lyapunov spectrum histogram for {samples} samples, ECA rule {rule}.")
ax.set_xlabel("Lyapunov coefficient")
ax.set_ylabel(f"Percentage (%)")
ax.text(lambdas_all.min(), N*samples/2-increment, f"{percentage_shown}% finite values.")

# %% [markdown]
# This **does not** correpond to the spectrum that Milan obtains. There is another mystery here. Why are the eigenvalues so scattered, and why are half of the eigenvalues negative (showing up as missing Lyapunov exponents)? That is impossible for rule 150, as it is an additive rule that will always spread the defect maximally. Is it possible that there are still some numerical issues here? To be fair, the numbers get very big very fast. Perhaps it's best to **calculate the Lyapunov spectrum of rule 150 by hand** (which should be possible because it has an explicit formula).

# %%
T = 10
J = jacobian(G_regular, ECA_as_LLNA, states)
Yt = calculate_Yt(G_regular, ECA_as_LLNA, states, T)
Gamma = Yt.dot(Yt.T)
Lambdas_all = np.linalg.eigvalsh(Gamma)

Lambdas_all

# %%
print(f"Rule {rule}\n")

states = np.random.randint(2,size=N)
lambdas_list = []
T = 400
delta_t = T // 20
ts = np.arange(delta_t, T+1, delta_t)
for t in ts:
    print(f"Working on t={t}", end='\r')
    Yt = calculate_Yt(G_regular, ECA_as_LLNA, states, t)
    lambdas = lyapunov_spectrum(Yt, t)
    lambdas = lambdas[np.isfinite(lambdas)]
    lambdas_list += [lambdas]

fig, ax = plt.subplots(1,1,figsize=(8, 3))
ax.boxplot(lambdas_list)
ax.set_title(f"Lyapunov spectrum for increasing values of $T$, ECA rule {rule}.")
ax.set_xticklabels(ts)
ax.set_xlabel(f"T values")
ax.set_ylabel(f"Lyapunov spectrum")

# %% [markdown]
# **QUESTION** can a single eigenvalue be related to the effect of a perturbation in a particular dimension? For CAs that does not really matter, as all dimensions are equivalent, but for NAs the individual nodes are quite distinct. It would be nice to know which node has a big influence, and which does not.

# %%
states = np.random.randint(2, size=N)
T_range = np.array(range(10, 511, 50))
lambdas_mins = []
lambdas_maxs = []

for T in T_range:
    print(f"Working on T={T}", end='\r')
    Yt = calculate_Yt(G, model, states, T)
    lambdas = lyapunov_spectrum(Yt, T)
    lambdas = lambdas[np.isfinite(lambdas)]
    lambdas_min = np.min(lambdas)
    lambdas_max = np.max(lambdas)
    lambdas_mins += [lambdas_min]
    lambdas_maxs += [lambdas_max]

fig, ax = plt.subplots(1,1,figsize=(10,3))
ax.plot(T_range, lambdas_maxs, label=f"maxima (ends at {round(lambdas_max,4)})")
ax.plot(T_range, lambdas_mins, label=f"finite minima (ends at {round(lambdas_min,4)})")

ax.plot(T_range, 10/T_range, 'k--', label='10/t (goes to zero)')

ax.set_xlabel(f"Number of time steps $T$")
ax.set_ylabel(f"Range of Lyapunov exponents $\lambda_i$")
ax.legend()

# %% [markdown]
# This is a **PROBLEM**, because it appears that all finite $\lambda_i$ converge to zero. That cannot be right! Additionally, the graph shows that the value of $\Lambda_i^t$ appears to be independent of time, and that the curve only goes down because of the inverse $t$ term.

# %% [markdown]
# ## 2.5 - Pipeline for computational experiments

# %% [markdown]
# (this is largely a transcription of the method expressed in the script, src and tests directories)

# %% [markdown]
# <hr>

# %% [markdown]
# # 3 - Results

# %% [markdown]
# ## 3.1 - First experiments with generating and ordering defect TEPs

# %% [markdown]
# ### _load a particular network and inspect some properties_

# %%
PATH = 'data/graphs/'
network_name = 'network_0000'

# Open the file and read its contents
with open(PATH+network_name+'.txt', 'r') as file:
    lines = file.readlines()

# Remove trailing newline characters from each line
lines = [line.strip() for line in lines]

N_nodes = int(lines[0].split(' ')[0])
N_edges = int(lines[0].split(' ')[1])

edges_raw = np.array(lines[6:])
edges = []
for i, edge_raw in enumerate(edges_raw):
    e_i = int(edge_raw.split(' ')[0])
    e_j = int(edge_raw.split(' ')[1])
    edges += [(e_i, e_j)]

G = ig.Graph()
G.add_vertices(range(N_nodes))
G.add_edges(edges)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))
    
ig.plot(G, target=ax, vertex_size=15)

# %%
# show properties per node, in the order they have been created by default
from matplotlib import cm
fig, axs = plt.subplots(2,2,figsize=(9,5))

degrees = G.degree()
closeness = G.closeness(normalized=True)
pagerank= G.pagerank()
clustering = G.transitivity_local_undirected()

cmap = cm.get_cmap('viridis')
colors = [cmap(.2), cmap(.4), cmap(.6), cmap(.8)]

axs[0,0].bar(range(N_nodes), degrees, width=1, color=colors[0])
axs[0,1].bar(range(N_nodes), closeness, width=1, color=colors[1])
axs[1,0].bar(range(N_nodes), pagerank, width=1, color=colors[2])
axs[1,1].bar(range(N_nodes), clustering, width=1, color=colors[3])

axs[0,0].set_title("Degree", y=.8)
axs[0,1].set_title("Closeness", y=.8)
axs[1,0].set_title("PageRank", y=.8)
axs[1,1].set_title("Clustering Coefficient", y=.8)

fig.suptitle("Various node properties.\n(Current node order based on Barabasi-Albert construction algorithm.)")

# %% [markdown]
# Clearly the default order of the nodes, which is a result of how the Barabasi-Albert graph has been constructed, is correlated to the four selected properties above. That is to say: there is some merit in using the default order as well.
#
# Now let's see what these distributions look like when we order them.

# %%
# show properties per node, in the order they have been created by default
from matplotlib import cm
fig, axs = plt.subplots(2,2,figsize=(9,5))

degrees = G.degree()
closeness = G.closeness(normalized=True)
pagerank= G.pagerank()
clustering = G.transitivity_local_undirected()

cmap = cm.get_cmap('viridis')
colors = [cmap(.2), cmap(.4), cmap(.6), cmap(.8)]

axs[0,0].bar(range(N_nodes), np.sort(degrees)[::-1], width=1, color=colors[0])
axs[0,1].bar(range(N_nodes), np.sort(closeness)[::-1], width=1, color=colors[1])
axs[1,0].bar(range(N_nodes), np.sort(pagerank)[::-1], width=1, color=colors[2])
axs[1,1].bar(range(N_nodes), np.sort(clustering)[::-1], width=1, color=colors[3])

axs[0,0].set_title("Degree (ordered)", y=.8)
axs[0,1].set_title("Closeness (ordered)", y=.8)
axs[1,0].set_title("PageRank (ordered)", y=.8)
axs[1,1].set_title("Clustering Coefficient (ordered)", y=.8)

fig.suptitle("Various node properties (nodes ordered based on the measure value).")

# %% [markdown]
# ### _Show ordered defect TEPs_
#
# First load some of the simulated TEPs, and find the associated defect TEP

# %%
from src.simulation import load_tensor
RES = 2
RULE = 'B1_S0'
PATH = f"data/teps/R={RES}/{RULE}/"

tep = load_tensor(PATH, network_name)
teps_defect = []
defect_nodes = [0, 5, 20, 50]

for defect_node in defect_nodes:
    tep_original = tep[0,0,:,:]
    tep_disturbed = tep[0,defect_node+1,:,:]
    tep_defect = abs(tep_original-tep_disturbed)
    teps_defect += [tep_defect]

# default defect TEP for various affected nodes
fig, axs = plt.subplots(2,2,figsize=(9,5), sharex=True, sharey=True)

axs[0,0].imshow(teps_defect[0], cmap='Greys')
axs[0,1].imshow(teps_defect[1], cmap='Greys')
axs[1,0].imshow(teps_defect[2], cmap='Greys')
axs[1,1].imshow(teps_defect[3], cmap='Greys')

axs[0,0].set_title(f"Original defect: node {defect_nodes[0]}")
axs[0,1].set_title(f"Original defect: node {defect_nodes[1]}")
axs[1,0].set_title(f"Original defect: node {defect_nodes[2]}")
axs[1,1].set_title(f"Original defect: node {defect_nodes[3]}")

fig.suptitle(f'Defect TEPs for various initial defects (rule {RULE})')
axs[0,0].set_ylabel(f'$\leftarrow$ Time')
axs[1,0].set_ylabel(f'$\leftarrow$ Time')
# plt.xlabel(f'Nodes (default order)')

# %% [markdown]
# Next, find representations in different orderings, based on the centrality measures.

# %%
degree_indices = np.argsort(degrees)[::-1]
closeness_indices = np.argsort(closeness)[::-1]
pagerank_indices = np.argsort(pagerank)[::-1]
clustering_indices = np.argsort(clustering)[::-1]

default_node = 0

tep_ordered_degree = np.array(teps_defect[default_node])[:,degree_indices]
tep_ordered_closeness = np.array(teps_defect[default_node])[:,closeness_indices]
tep_ordered_pagerank = np.array(teps_defect[default_node])[:,pagerank_indices]
tep_ordered_clustering = np.array(teps_defect[default_node])[:,clustering_indices]

from matplotlib.colors import LinearSegmentedColormap
LinearSegmentedColormap.from_list

cmap_degree = LinearSegmentedColormap.from_list('cmap_degree', [(1,1,1,1),colors[0]], N=2)
cmap_closeness = LinearSegmentedColormap.from_list('cmap_closeness', [(1,1,1,1),colors[1]], N=2)
cmap_pagerank = LinearSegmentedColormap.from_list('cmap_pagerank', [(1,1,1,1),colors[2]], N=2)
cmap_clustering = LinearSegmentedColormap.from_list('cmap_clustering', [(1,1,1,1),colors[3]], N=2)

fig, axs = plt.subplots(2,2,figsize=(9,5), sharex=True, sharey=True)

axs[0,0].imshow(tep_ordered_degree, cmap=cmap_degree)
axs[0,1].imshow(tep_ordered_closeness, cmap=cmap_closeness)
axs[1,0].imshow(tep_ordered_pagerank, cmap=cmap_pagerank)
axs[1,1].imshow(tep_ordered_clustering, cmap=cmap_clustering)

axs[0,0].set_title("Ordered per degree")
axs[0,1].set_title("Ordered per closeness factor")
axs[1,0].set_title("Ordered per PageRank value")
axs[1,1].set_title("Ordered per clustering coefficient")

# default defect TEP for various affected nodes
fig.suptitle(f'Defect TEPs for first-node initial defects (rule {RULE}), various orderings')

axs[0,0].set_ylabel(f'$\leftarrow$ Time')
axs[1,0].set_ylabel(f'$\leftarrow$ Time')
# plt.xlabel(f'Nodes (default order)')

# %% [markdown]
# This, of course, is still not really insightful.
#
# In a next step, we can try to extract a single property from the entire defect TEP (such as the radius of the defect subgraph), and plot this in function of the perturbed node. The order of the nodes (i.e. the convention as to what determines the 'second' node to be second, for example) may then demonstrate a particular relationship between a centrality measure and the NA robustness. This, in turn, can highlight which nodes play an important role in the NA and which may be altered without significant changes to the overall dynamics.
